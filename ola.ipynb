# %%
import pandas as pd
df=pd.read_csv('ola_booking.csv')
df.head()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_7024\850847822.py:2: DtypeWarning: Columns (0,1,2,3,4,5,6,7,10,11,12,13,15,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('ola_booking.csv')
#          Date      Time     Booking_ID        Booking_Status Customer_ID  \
# 0  26-07-2024  14:00:00  CNR7153255142    Canceled by Driver   CID713523
# 1  25-07-2024  22:20:00  CNR2940424040               Success   CID225428
# 2  30-07-2024  19:59:00  CNR2982357879               Success   CID270156
# 3  22-07-2024   3:15:00  CNR2395710036  Canceled by Customer   CID581320
# 4  02-07-2024   9:02:00  CNR1797421769               Success   CID939555
#
#   Vehicle_Type Pickup_Location Drop_Location  V_TAT  C_TAT  ...  \
# 0  Prime Sedan     Tumkur Road      RT Nagar    NaN    NaN  ...
# 1         Bike     Magadi Road       Varthur  203.0   30.0  ...
# 2    Prime SUV   Sahakar Nagar       Varthur  238.0  130.0  ...
# 3        eBike      HSR Layout   Vijayanagar    NaN    NaN  ...
# 4         Mini     Rajajinagar   Chamarajpet  252.0   80.0  ...
#
#        Canceled_Rides_by_Driver Incomplete_Rides Incomplete_Rides_Reason  \
# 0  Personal & Car related issue              NaN                     NaN
# 1                           NaN               No                     NaN
# 2                           NaN               No                     NaN
# 3                           NaN              NaN                     NaN
# 4                           NaN               No                     NaN
#
#   Booking_Value  Payment_Method Ride_Distance  Driver_Ratings  \
# 0         444.0             NaN           0.0             NaN
# 1         158.0            Cash          13.0             4.1
# 2         386.0             UPI          40.0             4.2
# 3         384.0             NaN           0.0             NaN
# 4         822.0     Credit Card          45.0             4.0
#
#    Customer_Rating  Vehicle Images Unnamed: 20
# 0              NaN          #NAME?         NaN
# 1              4.0          #NAME?         NaN
# 2              4.8          #NAME?         NaN
# 3              NaN          #NAME?         NaN
# 4              3.0          #NAME?         NaN
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103024 entries, 0 to 103023
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        20407 non-null  object
#  1   Time                        20407 non-null  object
#  2   Booking_ID                  20407 non-null  object
#  3   Booking_Status              20407 non-null  object
#  4   Customer_ID                 20407 non-null  object
#  5   Vehicle_Type                20407 non-null  object
#  6   Pickup_Location             20407 non-null  object
#  7   Drop_Location               20407 non-null  object
#  8   V_TAT                       12652 non-null  float64
#  9   C_TAT                       12652 non-null  float64
#  10  Canceled_Rides_by_Customer  2081 non-null   object
#  11  Canceled_Rides_by_Driver    3654 non-null   object
#  12  Incomplete_Rides            12652 non-null  object
#  13  Incomplete_Rides_Reason     795 non-null    object
#  14  Booking_Value               20407 non-null  float64
#  15  Payment_Method              12652 non-null  object
#  16  Ride_Distance               20407 non-null  float64
#  17  Driver_Ratings              12652 non-null  float64
#  18  Customer_Rating             12652 non-null  float64
#  19  Vehicle Images              20407 non-null  object
#  20  Unnamed: 20                 0 non-null      float64
# dtypes: float64(7), object(14)
# memory usage: 16.5+ MB

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Booking_ID', 'Booking_Status', 'Customer_ID',
#        'Vehicle_Type', 'Pickup_Location', 'Drop_Location', 'V_TAT', 'C_TAT',
#        'Canceled_Rides_by_Customer', 'Canceled_Rides_by_Driver',
#        'Incomplete_Rides', 'Incomplete_Rides_Reason', 'Booking_Value',
#        'Payment_Method', 'Ride_Distance', 'Driver_Ratings', 'Customer_Rating',
#        'Vehicle Images', 'Unnamed: 20'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 20', axis = 1)

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'Booking_ID', 'Booking_Status', 'Customer_ID',
#        'Vehicle_Type', 'Pickup_Location', 'Drop_Location', 'V_TAT', 'C_TAT',
#        'Canceled_Rides_by_Customer', 'Canceled_Rides_by_Driver',
#        'Incomplete_Rides', 'Incomplete_Rides_Reason', 'Booking_Value',
#        'Payment_Method', 'Ride_Distance', 'Driver_Ratings', 'Customer_Rating',
#        'Vehicle Images'],
#       dtype='object')

# %%
df = df.drop('Vehicle Images', axis = 1)

# %%
df.columns = df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['date', 'time', 'booking_id', 'booking_status', 'customer_id',
#        'vehicle_type', 'pickup_location', 'drop_location', 'v_tat', 'c_tat',
#        'canceled_rides_by_customer', 'canceled_rides_by_driver',
#        'incomplete_rides', 'incomplete_rides_reason', 'booking_value',
#        'payment_method', 'ride_distance', 'driver_ratings', 'customer_rating'],
#       dtype='object')

# %%
from urllib.parse import quote_plus
from sqlalchemy import create_engine


username = "postgres"
password = "@Skataria123"
host = "localhost"
port = "5432"
database = "ola_analysis"

encoded_password = quote_plus(password)
engine = create_engine(f"postgresql+psycopg2://{username}:{encoded_password}@{host}:{port}/{database}")

table_name = "booking"
df.to_sql(table_name, engine, if_exists="replace", index=False)
print(f"Data successfully loaded into table '{table_name}' , '{database}'." )
# Out:
# Data successfully loaded into table 'booking' , 'ola_analysis'.
